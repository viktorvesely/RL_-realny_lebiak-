# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
loss = np.load("./guts/loss.npy")
aws = np.load("./guts/aws.npy")
cws = np.load("./guts/cws.npy")
taws = np.load("./guts/taws.npy")
tcws = np.load("./guts/tcws.npy")
t = np.arange(loss.shape[1])

tw = np.arrange(aws.shape[0])

# %%
plt.plot(t, loss[0])

# %%
plt.plot(t, loss[1])

# %%
aws.shape
# Out:
# (701, 6)
